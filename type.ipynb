# %%
a = 23
b = ""
c = "23"
d = 5.5
e = 5.0
f = True
g = ()
h = {}
i = []
j = 4,5,6

# %%
type (a)
# Out:
# int

# %%
type (b)
# Out:
# str

# %%
type (c)
# Out:
# str

# %%
type (d)
# Out:
# float

# %%
type (f)
# Out:
# bool

# %%
type (e)
# Out:
# float

# %%
type (g)
# Out:
# tuple

# %%
type (h)
# Out:
# dict

# %%
type (i)
# Out:
# list

# %%
type (j)
# Out:
# tuple

# %%
S = {20, 'Jessa', 35.75}

# %%
type (S)
# Out:
# set
