# %%
a = 0
b = 1
c = 10
d = 100
e = 425
f = 7
g = "ali"
h = 'ali'
i = ""
j = ''

# %%
not a
# Out:
# True

# %%
not b
# Out:
# False

# %%
a or b
# Out:
# 1

# %%
b or a
# Out:
# 1

# %%
b or c
# Out:
# 1

# %%
c or b
# Out:
# 10

# %%
a and b
# Out:
# 0

# %%
b and b
# Out:
# 1

# %%
b and a
# Out:
# 0

# %%
b and c
# Out:
# 10

# %%
b and d
# Out:
# 100

# %%
b or d
# Out:
# 1

# %%
a is b
# Out:
# False

# %%
a is a
# Out:
# True

# %%
not j
# Out:
# True

# %%
not h
# Out:
# False

# %%
not i
# Out:
# True

# %%
h or i
# Out:
# 'ali'

# %%
i or h
# Out:
# 'ali'

# %%
h and i
# Out:
# ''

# %%
i and h
# Out:
# ''
