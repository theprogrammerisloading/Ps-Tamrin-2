# %%
a = 1
b = 2
c = 1
d = ""
e = "mahdi"
f = ''
g = ' '
h = 0
i = "ahmad"

# %%
a is b
# Out:
# False

# %%
a is c
# Out:
# True

# %%
d is f
# Out:
# True

# %%
g is f
# Out:
# False

# %%
d is g
# Out:
# False

# %%
a is h
# Out:
# False

# %%
a = h

# %%
a is h
# Out:
# True

# %%
print (h,a)
# Out:
# 0 0

# %%
print (i,e)
# Out:
# ahmad mahdi

# %%
i = e

# %%
i is e
# Out:
# True

# %%
e is i
# Out:
# True

# %%
print (e,i)
# Out:
# mahdi mahdi
